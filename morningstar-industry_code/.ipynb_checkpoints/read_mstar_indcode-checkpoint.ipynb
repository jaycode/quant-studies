# %%
import pandas as pd

df = pd.read_csv('morningstar-industry_code.tsv', sep='\t', header=None, names=['Super Sector Name', 'Super Sector Code', 'Sector Name', 'Sector Code',
                                                                                'Group Name', 'Group Code', 'Industry Name', 'Industry Code'])

# %%
df
# Out:
#     Super Sector Name  Super Sector Code      Sector Name  Sector Code  \
# 0            Cyclical                  1  Basic Materials          101
# 1            Cyclical                  1  Basic Materials          101
# 2            Cyclical                  1  Basic Materials          101
# 3            Cyclical                  1  Basic Materials          101
# 4            Cyclical                  1  Basic Materials          101
# ..                ...                ...              ...          ...
# 140         Sensitive                  3       Technology          311
# 141         Sensitive                  3       Technology          311
# 142         Sensitive                  3       Technology          311
# 143         Sensitive                  3       Technology          311
# 144         Sensitive                  3       Technology          311
#
#              Group Name  Group Code                        Industry Name  \
# 0           Agriculture       10110                  Agricultural Inputs
# 1    Building Materials       10120                   Building Materials
# 2             Chemicals       10130                            Chemicals
# 3             Chemicals       10130                  Specialty Chemicals
# 4       Forest Products       10140             Lumber & Wood Production
# ..                  ...         ...                                  ...
# 140            Hardware       31120  Electronics & Computer Distribution
# 141            Hardware       31120   Scientific & Technical Instruments
# 142      Semiconductors       31130  Semiconductor Equipment & Materials
# 143      Semiconductors       31130                       Semiconductors
# 144      Semiconductors       31130                                Solar
#
#      Industry Code
# 0         10110010
# 1         10120010
# 2         10130010
# 3         10130020
# 4         10140010
# ..             ...
# 140       31120050
# 141       31120060
# 142       31130010
# 143       31130020
# 144       31130030
#
# [145 rows x 8 columns]
